# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from surprise.model_selection.split import train_test_split
from surprise import Dataset, Reader , KNNBasic
themes= pd.read_csv("themes.csv")
users = pd.read_csv("users.csv")
themes.head()
# Out:
#    themesid                                              titel  \
# 0         1  CONCEPTION D’UN SYSTÈME D’INFORMATION  \nET DÉ...
# 1         2  TRAITEMENT DE L'INFORMATION \nGÉOGRAPHIQUE DAN...
# 2         3  TECHNIQUES DE GÉNÉRATION DES SCRIPTS DE \nRECO...
# 3         4  RÉALISATION D'UNE APPLICATION MOBILE POUR LA\n...
# 4         5  CONCEPTION ET DÉVELOPPEMENT DU MODULE RECRUTEM...
#
#                                             keywords
# 0  IL | Architecture de l'information | Conceptio...
# 1  IL | Collecte de données | Traitement de donné...
# 2  IL | Analyse de code source | Interprétation s...
# 3  IL | Développement d'applications mobiles | Sé...
# 4  IL | Collecte des besoins | Développement web ...

# %%
df = themes.merge(users , how ="left" , on ="themesid")
columns_titles = ["themesid","userid","titel","keywords","liked"]
df=df.reindex(columns=columns_titles)
df.dropna()
# Out:
#     themesid  userid                                              titel  \
# 0          1     1.0  CONCEPTION D’UN SYSTÈME D’INFORMATION  \nET DÉ...
# 1          1     3.0  CONCEPTION D’UN SYSTÈME D’INFORMATION  \nET DÉ...
# 4          4     2.0  RÉALISATION D'UNE APPLICATION MOBILE POUR LA\n...
# 11        11     3.0  CONCEPTION D'UN DATAWAREHOUSE ET MISE EN PLACE...
# 12        11     1.0  CONCEPTION D'UN DATAWAREHOUSE ET MISE EN PLACE...
# 13        12     1.0  TECHNIQUES DE MACHINE LEARNING POUR LA \nDÉTEC...
# 14        12     3.0  TECHNIQUES DE MACHINE LEARNING POUR LA \nDÉTEC...
# 15        13     1.0  PROPOSITION ET CONCEPTION D'UNE SOLUTION \nDMV...
# 16        13     2.0  PROPOSITION ET CONCEPTION D'UNE SOLUTION \nDMV...
# 17        14     1.0  CONCEPTION ET RÉALISATION D'UNE PLATE-FORME DE...
# 18        14     2.0  CONCEPTION ET RÉALISATION D'UNE PLATE-FORME DE...
# 19        15     1.0  LA RÉALISATION D’UNE APPLICATION WEB POUR LA \...
# 20        15     3.0  LA RÉALISATION D’UNE APPLICATION WEB POUR LA \...
# 21        16     1.0            ETUDE ET DEPLOYEMENT D'UN SERVEUR VPN\n
# 25        20     1.0  ETUDE ET RÉALISATION D'UN SYSTÈME DE \nRECONNA...
#
#                                              keywords  liked
# 0   IL | Architecture de l'information | Conceptio...    1.0
# 1   IL | Architecture de l'information | Conceptio...    0.0
# 4   IL | Développement d'applications mobiles | Sé...    1.0
# 11  BIG DATA | Datawarehouse | Modélisation de don...    1.0
# 12  BIG DATA | Datawarehouse | Modélisation de don...    1.0
# 13  BIG DATA | Machine Learning | Réseaux de neuro...    1.0
# 14  BIG DATA | Machine Learning | Réseaux de neuro...    0.0
# 15  GTR | Réseau | Sécurité de l'information | Int...    0.0
# 16  GTR | Réseau | Sécurité de l'information | Int...    1.0
# 17  GTR | Robotique |  Technologie de suivi solair...    1.0
# 18  GTR | Robotique |  Technologie de suivi solair...    0.0
# 19  GTR | Plateforme d'apprentissage | devlopment ...    1.0
# 20  GTR | Plateforme d'apprentissage | devlopment ...    0.0
# 21  GTR | Sécurité des données | Réseau informatiq...    0.0
# 25  ISIL | ISIL | Vision par ordinateur | Traiteme...    0.0

# %%
reader = Reader(rating_scale=(1, 5))
dataset = Dataset.load_from_df(df[['userid', 'themesid','liked']], reader)
trainset, testset = train_test_split(dataset, test_size=0.20)
sim_options = {'name': 'cosine', 'user_based': True}
model = KNNBasic(sim_options=sim_options)
model.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
# Make hybrid recommendations

tfidf = TfidfVectorizer(stop_words='english')
post_features = tfidf.fit_transform(df['titel'])
# Train a content-based filtering model
post_similarity = cosine_similarity(post_features) 

user_id = 1
n_recommendations = 10
liked_posts = df[df['userid'] == user_id]['themesid'].tolist() #post li darlhom like deja 
liked_posts_sim = post_similarity[liked_posts, :] #hna ydir similarity matrix bin li darlhom like w lokhrin 
cf_predictions = model.test([(user_id, themesid, 1) for themesid in liked_posts])
cf_predictions = {pred.iid: pred.est for pred in cf_predictions} #ydirlk collaborative filtring based user previosly ratings
cb_predictions = liked_posts_sim.sum(axis=0) 
cb_predictions = {idx: score for idx, score in enumerate(cb_predictions)} #generate a theme based collaborative filtring 
hybrid_predictions = {}
for themesid in cb_predictions: #and we merge theme here 
    if themesid not in cf_predictions:
        hybrid_predictions[themesid] = cb_predictions[themesid]
    else:
        hybrid_predictions[themesid] = 0.5 * cf_predictions[themesid] + 0.5 * cb_predictions[themesid]

# %%
print(hybrid_predictions)
# Out:
# {0: 1.5349144154627772, 1: 1.2674572077313886, 2: 0.24400400354995883, 3: 0.37564135521104586, 4: 0.8781762848600668, 5: 0.7797315558092672, 6: 0.2575339437080197, 7: 0.3256416286575408, 8: 0.7593298547758845, 9: 0.5411056587764804, 10: 0.1605788814309074, 11: 1.7898351752853006, 12: 1.7898351752853006, 13: 3.6843390113997962, 14: 1.6843390113997965, 15: 1.7638017424646246, 16: 1.7638017424646246, 17: 0.6326018720198046, 18: 0.6326018720198046, 19: 1.8197147290446831, 20: 1.4098573645223416, 21: 0.18472008659200997, 22: 0.8915488042096966, 23: 0.8915488042096966, 24: 0.2894385630486889, 25: 0.6342936252198229, 26: 0.9079938749479125, 27: 1.3106018244791982, 28: 1.5349144154627772, 29: 0.9907374698207809, 30: 0.23182840321809275, 31: 0.4845407105053745, 32: 0.476716706417448, 33: 0.8766464577324009, 34: 0.1120947425712181, 35: 0.305850370857914, 36: 0.4439448075264291, 37: 0.9363999314464393, 38: 1.0132261505901485, 39: 0.4329892785854838, 40: 1.1490343701152173, 41: 0.5031110225841361, 42: 1.2541226224108437, 43: 0.5600934476450999, 44: 0.30629559283770946, 45: 1.22905695991114, 46: 0.0, 47: 0.47906013066642117, 48: 0.45198900366536326, 49: 0.312642646570308, 50: 0.6664955110189927, 51: 0.6543456382330837, 52: 0.28265695757520126, 53: 0.0, 54: 0.29206596517161, 55: 0.08217125092094521, 56: 0.489946289507252, 57: 0.13051637812443073, 58: 0.88422481073641, 59: 0.6276460469582653, 60: 0.6870201467434448, 61: 0.7160695946344278, 62: 0.08457033560755474, 63: 0.43062711189278746, 64: 0.14090809547056, 65: 0.0}
